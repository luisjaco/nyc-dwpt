# %%
import pandas as pd
import numpy as np
import scipy.stats as scipy
import matplotlib.pyplot as pyplot
import seaborn

# %%
def perform(df_list, func): 
    for df in df_list:
        func(df)

# %%
t3 = pd.read_csv('testing_traffic3.csv')
t2 = pd.read_csv('testing_traffic2.csv')
t1 = pd.read_csv('testing_traffic1.csv')
data = [t3, t2, t1]
# lets see all data statistics
perform(data, lambda df: print(df.info(), end="\n\n"))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18509 entries, 0 to 18508
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   vehicle_id  18509 non-null  object
#  1   total_time  18509 non-null  int64
# dtypes: int64(1), object(1)
# memory usage: 289.3+ KB
# None
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13550 entries, 0 to 13549
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   vehicle_id  13550 non-null  object
#  1   total_time  13550 non-null  int64
# dtypes: int64(1), object(1)
# memory usage: 211.8+ KB
# None
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6897 entries, 0 to 6896
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   vehicle_id  6897 non-null   object
#  1   total_time  6897 non-null   int64
# dtypes: int64(1), object(1)
# memory usage: 107.9+ KB
# None

# %%
perform(data, display)
# Out:
#       vehicle_id  total_time
# 0          veh64          50
# 1        veh64.1          49
# 2        veh64.2          64
# 3         veh112          53
# 4       veh112.1          51
# ...          ...         ...
# 18504  veh6342.2         820
# 18505  veh6780.2         618
# 18506  veh7791.2         187
# 18507  veh7901.1         142
# 18508    veh8002         101
#
# [18509 rows x 2 columns]
#       vehicle_id  total_time
# 0          veh64          57
# 1        veh64.1          56
# 2         veh112          54
# 3       veh112.1          53
# 4          veh69          86
# ...          ...         ...
# 13545    veh6845         607
# 13546    veh7140         478
# 13547    veh7296         410
# 13548  veh7296.1         407
# 13549  veh7558.1         292
#
# [13550 rows x 2 columns]
#      vehicle_id  total_time
# 0         veh64          65
# 1        veh112          48
# 2         veh69          85
# 3         veh76         100
# 4         veh40         119
# ...         ...         ...
# 6892    veh7768         200
# 6893    veh7212         445
# 6894    veh7773         200
# 6895    veh7527         309
# 6896    veh7547         300
#
# [6897 rows x 2 columns]

# %%
# create time_in_hour column
# since the first step is 0, we'll add one to all values
# then we will divide each by 3600
for df in data:
    df['total_seconds'] += 1
    df['total_hours'] = df['total_time'] / 3600
display(data[0])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'total_seconds'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[66], line 5
#       1 # create time_in_hour column
#       2 # since the first step is 0, we'll add one to all values
#       3 # then we will divide each by 3600
#       4 for df in data:
# ----> 5     df['total_seconds'] += 1
#       6     df['total_hours'] = df['total_time'] / 3600
#       7 display(data[0])
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'total_seconds'

# %%
# lets check statistics
perform(data, lambda df: print(df.describe(), end="\n\n"))
# Out:
#          total_time   total_hours
# count  18509.000000  18509.000000
# mean     476.633476      0.132398
# std      298.649854      0.082958
# min       32.000000      0.008889
# 25%      268.000000      0.074444
# 50%      412.000000      0.114444
# 75%      608.000000      0.168889
# max     3217.000000      0.893611
#
#          total_time   total_hours
# count  13550.000000  13550.000000
# mean     360.693358      0.100193
# std      178.787889      0.049663
# min       28.000000      0.007778
# 25%      231.000000      0.064167
# 50%      333.000000      0.092500
# 75%      461.000000      0.128056
# max     1537.000000      0.426944
#
#         total_time  total_hours
# count  6897.000000  6897.000000
# mean    311.351457     0.086487
# std     136.659470     0.037961
# min      33.000000     0.009167
# 25%     209.000000     0.058056
# 50%     297.000000     0.082500
# 75%     394.000000     0.109444
# max    1054.000000     0.292778

# %%
# lets plot for t1
t1_time_mean = np.mean(t1.total_hours)
pyplot.hist(data=t1, x='total_hours', bins=100)
pyplot.title(f'trip time where traffic=1\n{len(t1)} trips\nmean: {t1_time_mean}')
pyplot.axvline(x=t1_time_mean).set_color('pink')
pyplot.plot()
# Out:
# []

# %%
# lets plot for t2
t2_time_mean = np.mean(t2.total_hours)
pyplot.hist(data=t2, x='total_hours', bins=100)
pyplot.title(f'trip time where traffic=2\n{len(t2)} trips\nmean: {t2_time_mean}')
pyplot.axvline(x=t2_time_mean).set_color('pink')
pyplot.plot()
# Out:
# []

# %%
# lets plot for t3
t3_time_mean = np.mean(t3.total_hours)
pyplot.hist(data=t3, x='total_hours', bins=100)
pyplot.title(f'trip time where traffic=3\n{len(t3)} trips\nmean: {t3_time_mean}')
pyplot.axvline(x=t3_time_mean).set_color('pink')
pyplot.plot()
# Out:
# []
